# %% [markdown]
# Latent Semantic Analysis

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['rec.sport.baseball']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# Making Stop words

# %%
stopset = set(stopwords.words('english'))
stopset.update(['lt','p','/p','br','amp','quot','field','font','normal','span','0gx','rgb','style','51','spacing','text','helvetica','size','family','space','arial','height','lindent','letter','line','none','sans','serif','transform','line','variant','weight','times','strong','new','video','title','white','word','letter','roman','Opt','16','color','12','14','21','neve','apple','class',])

# %%
nltk.download()
# Out:
# showing info http://nltk.github.com/nltk_data/
# True

# %% [markdown]
# TF-IDF Vectorizing

# %%
corpus[0]
# Out:
# u"From: writingctr@leo.bsuvc.bsu.edu\nSubject: Re: CUB fever.\nOrganization: Ball State University, Muncie, In - Univ. Computing Svc's\nLines: 21\n\n\nIn article <kingoz.735285670@camelot>, kingoz@camelot.bradley.edu (Orin Roth) writes:\n> \n>    CUB fever is hitting me again. I'm beginning to think they have a \n>    chance this year. (what the heck am i thinking?)\n>    Sorry. Just a moment of incompetence.\n>    I'll be ok. Really. \n>    Orin.\n>    Bradley U.\n> \n> --\n> I'm really a jester in disguise!                                   \nI hear ya!  Then again, we must remember that we are indeed Cub fans, and\nthat the Cubs will eventually blow it.  After all, the Cubs are the easiest\nteam in the National League to root for.  No Pressure.  You know they will\nlose eventually.  Oh well, I suppose we must have faith.  After all, they\ndo look pretty good, and they don't even have Sandberg back yet.  \n\nCUBS IN '93!!!!!\n\nCHA\n"

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x190051 sparse matrix of type '<type 'numpy.float64'>'
# 	with 235 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 51475)	0.0734463096625
#   (0, 189323)	0.0734463096625
#   (0, 28954)	0.0734463096625
#   (0, 146580)	0.0734463096625
#   (0, 64428)	0.0734463096625
#   (0, 77938)	0.0734463096625
#   (0, 133180)	0.0734463096625
#   (0, 103446)	0.0734463096625
#   (0, 66814)	0.0734463096625
#   (0, 114541)	0.0734463096625
#   (0, 163286)	0.0734463096625
#   (0, 181094)	0.0734463096625
#   (0, 119646)	0.0734463096625
#   (0, 64564)	0.0734463096625
#   (0, 103940)	0.0734463096625
#   (0, 95553)	0.0734463096625
#   (0, 133095)	0.0734463096625
#   (0, 143744)	0.0734463096625
#   (0, 98147)	0.0734463096625
#   (0, 115182)	0.0734463096625
#   (0, 165645)	0.0734463096625
#   (0, 59684)	0.0734463096625
#   (0, 51515)	0.0734463096625
#   (0, 35722)	0.0734463096625
#   (0, 64554)	0.0734463096625
#   :	:
#   (0, 143978)	0.0551931192048
#   (0, 122313)	0.11038623841
#   (0, 37511)	0.0989842910659
#   (0, 40681)	0.104524831508
#   (0, 16529)	0.0734463096625
#   (0, 94964)	0.11038623841
# ...

# %% [markdown]
# LSA

# %%
X.shape
# Out:
# (994, 190051)

# %%
lsa=TruncatedSVD(n_components=27,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=27, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01597904,  0.00498283,  0.00080901, ...,  0.00102609,
#         0.00102609,  0.00102609])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu
#
# com
#
# year
#
# writes
#
# team
#
# would
#
# game
#
# article
#
# re
#
# cs
#
# Concept 1:
# host
#
# jewish
#
# braves
#
# baseball
#
# writes article
#
# people
#
# scott
#
# players
#
# edu organization
#
# lafayette
#
# Concept 2:
# edu
#
# host
#
# re
#
# nntp
#
# news
#
# nntp posting host
#
# posting host
#
# hit
#
# run
#
# first
#
# Concept 3:
# game
#
# get
#
# baseball
#
# hit
#
# games
#
# bonds
#
# also
#
# season
#
# time
#
# many
#
# Concept 4:
# first
#
# games
#
# nntp posting host
#
# posting host
#
# best
#
# think
#
# player
#
# re
#
# clutch
#
# ball
#
# Concept 5:
# com
#
# well
#
# would
#
# good
#
# subject
#
# hitter
#
# let
#
# netcom
#
# netcom com
#
# players
#
# Concept 6:
# time
#
# season
#
# hit
#
# duke
#
# well
#
# runs
#
# see
#
# make
#
# jewish
#
# netcom
#
# Concept 7:
# think
#
# league
#
# 00
#
# pitcher
#
# host
#
# make
#
# average
#
# university
#
# john
#
# win
#
# Concept 8:
# posting
#
# baseball
#
# like
#
# ...

# %%
stopset = set(stopwords.words('english'))
stopset.update(['lt','p','/p','br','amp','quot','field','font','normal','span','0gx','rgb','style','51','spacing','text','helvetica','size','family','space','arial','height','lindent','letter','line','none','sans','serif','transform','line','variant','weight','times','strong','Opt','16','color','12','14','21','neve','apple','class',])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu
#
# com
#
# year
#
# writes
#
# team
#
# would
#
# game
#
# article
#
# re
#
# cs
#
# Concept 1:
# host
#
# jewish
#
# braves
#
# baseball
#
# writes article
#
# people
#
# scott
#
# players
#
# edu organization
#
# lafayette
#
# Concept 2:
# edu
#
# host
#
# re
#
# nntp
#
# news
#
# nntp posting host
#
# posting host
#
# hit
#
# run
#
# first
#
# Concept 3:
# game
#
# get
#
# baseball
#
# hit
#
# games
#
# bonds
#
# also
#
# season
#
# time
#
# many
#
# Concept 4:
# first
#
# games
#
# nntp posting host
#
# posting host
#
# best
#
# think
#
# player
#
# re
#
# clutch
#
# ball
#
# Concept 5:
# com
#
# well
#
# would
#
# good
#
# subject
#
# hitter
#
# let
#
# netcom
#
# netcom com
#
# players
#
# Concept 6:
# time
#
# season
#
# hit
#
# duke
#
# well
#
# runs
#
# see
#
# make
#
# jewish
#
# netcom
#
# Concept 7:
# think
#
# league
#
# 00
#
# pitcher
#
# host
#
# make
#
# average
#
# university
#
# john
#
# win
#
# Concept 8:
# posting
#
# baseball
#
# like
#
# ...

# %%
corpus[1]
# Out:
# u'From: schmke@cco.caltech.edu (Kevin Todd Schmidt)\nSubject: NL OPI through first week+\nOrganization: California Institute of Technology, Pasadena\nLines: 184\nNNTP-Posting-Host: sandman.caltech.edu\n\nHere is the OPI (Offensive Production Index) for all NL players with at\nleast 10 at-bats.\n\nIt is early in the season so there are some high numbers.  Barry Bonds\nfinished last season at 0.795.\n\nI welcome comments and suggestions.\n\nKevin\n\nLeague OPI: 0.410\nLeague BA:  0.252\nLeague SLG: 0.375\nLeague OBA: 0.321\n\nRank Player                 OPI     BA    SLG    OBA\n-----------------------------------------------------\n1    Phi,daulton           1.101  0.333  0.875  0.515\n2    Phi,kruk              1.069  0.429  0.821  0.529\n3    Cub,grace             1.007  0.452  0.742  0.514\n4    Cub,may               0.931  0.389  0.889  0.421\n5    Col,boston            0.888  0.545  0.545  0.545\n6    Pit,bell              0.873  0.429  0.714  0.467\n7    Col,galarraga         0.
# ...

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(2,5))
X=vectorizer.fit_transform(corpus)

# %%
X[1]
# Out:
# <1x386021 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4511 stored elements in Compressed Sparse Row format>

# %%
print X[1]
# Out:
#   (0, 27835)	0.0136939866388
#   (0, 157424)	0.0136939866388
#   (0, 231898)	0.0136939866388
#   (0, 186433)	0.0136939866388
#   (0, 316835)	0.0136939866388
#   (0, 299536)	0.0136939866388
#   (0, 115814)	0.0136939866388
#   (0, 159334)	0.0136939866388
#   (0, 239929)	0.0136939866388
#   (0, 26668)	0.0136939866388
#   (0, 119218)	0.0136939866388
#   (0, 79852)	0.0136939866388
#   (0, 84002)	0.0136939866388
#   (0, 299559)	0.0136939866388
#   (0, 192392)	0.0136939866388
#   (0, 272368)	0.0136939866388
#   (0, 184035)	0.0136939866388
#   (0, 63688)	0.0136939866388
#   (0, 36290)	0.0136939866388
#   (0, 63613)	0.0136939866388
#   (0, 240157)	0.0136939866388
#   (0, 36395)	0.0136939866388
#   (0, 173864)	0.0136939866388
#   (0, 24076)	0.0136939866388
#   (0, 19525)	0.0136939866388
#   :	:
#   (0, 245320)	0.0136939866388
#   (0, 121473)	0.0136939866388
#   (0, 296968)	0.0131149979662
#   (0, 172398)	0.0131149979662
#   (0, 267287)	0.003641139838
#   (0, 237152)	0.003641139838
# ...

# %%
X.shape
# Out:
# (994, 386021)

# %%
lsa=TruncatedSVD(n_components=27,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=27, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([  2.48094917e-04,   7.46119405e-05,   2.66471216e-05, ...,
#          9.05007636e-05,   9.05007636e-05,   9.05007636e-05])

# %%
lsa.components_[2]
# Out:
# array([ 0.0019399 ,  0.00041832,  0.00014603, ...,  0.00147328,
#         0.00147328,  0.00147328])

# %%
lsa.components_[3]
# Out:
# array([ -6.07133343e-04,  -9.69083199e-05,  -3.95714926e-05, ...,
#          1.55293147e-04,   1.55293147e-04,   1.55293147e-04])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu vb30
#
# lafayette edu
#
# lafayette edu vb30
#
# lafibm lafayette
#
# lafibm lafayette edu
#
# lafibm lafayette edu vb30
#
# jewish baseball
#
# baseball players
#
# jewish baseball players
#
# john lowenstein
#
# Concept 1:
# journalism indiana
#
# journalism indiana edu
#
# indiana edu
#
# dwarner journalism
#
# dwarner journalism indiana
#
# dwarner journalism indiana edu
#
# mail 411
#
# 1993 rap
#
# 1993 rap art
#
# 1993 rap art ep
#
# Concept 2:
# gatech edu
#
# duke edu
#
# ibm com
#
# econ duke
#
# prism gatech
#
# prism gatech edu
#
# aix kingston
#
# aix kingston ibm
#
# aix kingston ibm com
#
# kingston ibm
#
# Concept 3:
# asd com
#
# scott asd
#
# scott asd com
#
# scott barman
#
# com scott
#
# com mail
#
# asd com scott
#
# asd com scott barman
#
# com scott barman
#
# scott asd com scott
#
# Concept 4:
# jhu edu
#
# jhunix hcf
#
# jhunix hcf jhu
#
# jhunix hcf jhu edu
#
# hcf jhu
#
# hcf jhu edu
#
# scott asd
#
# scott asd com
#
# scott barman
#
# ...

# %% [markdown]
# Removing some stop words from the previous stop words

# %%
stopset = set(stopwords.words('english'))
stopset.update(['lt','p','/p','br','amp','quot','field','font','normal','span','0gx','rgb','style','51','spacing','text','helvetica','size','family','space','arial','height','lindent','letter','line','none','sans','serif','16','color','12','14','21','neve','apple','class',])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu vb30
#
# lafayette edu
#
# lafayette edu vb30
#
# lafibm lafayette
#
# lafibm lafayette edu
#
# lafibm lafayette edu vb30
#
# jewish baseball
#
# baseball players
#
# jewish baseball players
#
# john lowenstein
#
# Concept 1:
# journalism indiana
#
# journalism indiana edu
#
# indiana edu
#
# dwarner journalism
#
# dwarner journalism indiana
#
# dwarner journalism indiana edu
#
# mail 411
#
# 1993 rap
#
# 1993 rap art
#
# 1993 rap art ep
#
# Concept 2:
# gatech edu
#
# duke edu
#
# ibm com
#
# econ duke
#
# prism gatech
#
# prism gatech edu
#
# aix kingston
#
# aix kingston ibm
#
# aix kingston ibm com
#
# kingston ibm
#
# Concept 3:
# asd com
#
# scott asd
#
# scott asd com
#
# scott barman
#
# com scott
#
# com mail
#
# asd com scott
#
# asd com scott barman
#
# com scott barman
#
# scott asd com scott
#
# Concept 4:
# jhu edu
#
# jhunix hcf
#
# jhunix hcf jhu
#
# jhunix hcf jhu edu
#
# hcf jhu
#
# hcf jhu edu
#
# scott asd
#
# scott asd com
#
# scott barman
#
# ...

# %%
corpus[4]
# Out:
# u'From: jja2h@Virginia.EDU ("")\nSubject: Re: Yankee fears.\nOrganization: University of Virginia\nLines: 8\n\nHow can anyone pick the worst Yankee pitcher.  In the past 12\nyears there have been so many.\n\nDoes the name Steve "You mean I should try and throw the ball\nto the catcher" Trout?\n\nJonathan Alboum\nUVA\n'

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x190577 sparse matrix of type '<type 'numpy.float64'>'
# 	with 235 stored elements in Compressed Sparse Row format>

# %%
X[4]
# Out:
# <1x190577 sparse matrix of type '<type 'numpy.float64'>'
# 	with 85 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 51456)	0.0734463096625
#   (0, 189848)	0.0734463096625
#   (0, 28953)	0.0734463096625
#   (0, 146727)	0.0734463096625
#   (0, 64400)	0.0734463096625
#   (0, 77905)	0.0734463096625
#   (0, 133328)	0.0734463096625
#   (0, 103408)	0.0734463096625
#   (0, 66786)	0.0734463096625
#   (0, 114498)	0.0734463096625
#   (0, 163492)	0.0734463096625
#   (0, 181467)	0.0734463096625
#   (0, 119796)	0.0734463096625
#   (0, 64536)	0.0734463096625
#   (0, 103902)	0.0734463096625
#   (0, 95518)	0.0734463096625
#   (0, 133243)	0.0734463096625
#   (0, 143892)	0.0734463096625
#   (0, 98114)	0.0734463096625
#   (0, 115139)	0.0734463096625
#   (0, 165852)	0.0734463096625
#   (0, 59657)	0.0734463096625
#   (0, 51496)	0.0734463096625
#   (0, 35719)	0.0734463096625
#   (0, 64526)	0.0734463096625
#   :	:
#   (0, 144126)	0.0551931192048
#   (0, 122461)	0.11038623841
#   (0, 37507)	0.0989842910659
#   (0, 40677)	0.104524831508
#   (0, 16526)	0.0734463096625
#   (0, 94929)	0.11038623841
# ...

# %%
print X[4]
# Out:
#   (0, 93088)	0.119179263048
#   (0, 173275)	0.131856225313
#   (0, 42192)	0.131856225313
#   (0, 29506)	0.131856225313
#   (0, 169716)	0.131856225313
#   (0, 173536)	0.131856225313
#   (0, 109321)	0.131856225313
#   (0, 160212)	0.131856225313
#   (0, 114966)	0.131856225313
#   (0, 107170)	0.131856225313
#   (0, 189469)	0.131856225313
#   (0, 124569)	0.131856225313
#   (0, 127873)	0.131856225313
#   (0, 187884)	0.131856225313
#   (0, 185244)	0.131856225313
#   (0, 126986)	0.131856225313
#   (0, 24138)	0.131856225313
#   (0, 101356)	0.131856225313
#   (0, 178493)	0.131856225313
#   (0, 175904)	0.0962674929021
#   (0, 122332)	0.0962674929021
#   (0, 67940)	0.124440677765
#   (0, 187868)	0.119179263048
#   (0, 138045)	0.119179263048
#   (0, 162549)	0.102421230472
#   :	:
#   (0, 109206)	0.0681878580675
#   (0, 114861)	0.0653284462569
#   (0, 107048)	0.0512617784543
#   (0, 124458)	0.0660650152193
#   (0, 23999)	0.0500744654864
#   (0, 67935)	0.115098192737
#   (0, 187846)	0.149022402187
# ...

# %%
X.shape
# Out:
# (994, 190577)

# %%
X[4]
# Out:
# <1x190577 sparse matrix of type '<type 'numpy.float64'>'
# 	with 85 stored elements in Compressed Sparse Row format>

# %%
X.shape
# Out:
# (994, 190577)

# %%
lsa=TruncatedSVD(n_components=27,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=27, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01618102,  0.00504852,  0.00083791, ...,  0.00102956,
#         0.00102956,  0.00102956])

# %%
lsa.components_[1]
# Out:
# array([-0.01784197, -0.00359706, -0.00214605, ...,  0.00107011,
#         0.00107011,  0.00107011])

# %%
lsa.components_[4]
# Out:
# array([ -2.72452192e-02,   2.33342516e-03,   8.27348726e-05, ...,
#         -2.14493923e-03,  -2.14493923e-03,  -2.14493923e-03])

# %%
lsa.components_[10]
# Out:
# array([ -4.10044551e-02,  -2.83208156e-03,  -1.33910890e-03, ...,
#          2.24732703e-06,   2.24732703e-06,   2.24732703e-06])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu
#
# com
#
# year
#
# writes
#
# team
#
# would
#
# game
#
# article
#
# re
#
# cs
#
# Concept 1:
# jewish
#
# players
#
# edu
#
# much
#
# writes article
#
# come
#
# princeton edu
#
# gant
#
# base
#
# article
#
# Concept 2:
# edu
#
# writes
#
# like
#
# years
#
# many
#
# well
#
# subject
#
# know
#
# cs
#
# article
#
# Concept 3:
# think
#
# hit
#
# posting
#
# clutch
#
# many
#
# jays
#
# good
#
# organization university
#
# pretty
#
# two
#
# Concept 4:
# see
#
# year
#
# hirschbeck
#
# gant
#
# writes
#
# people
#
# uiuc edu
#
# far
#
# winfield
#
# ibm
#
# Concept 5:
# com
#
# one
#
# ibm
#
# host
#
# could
#
# give
#
# lines
#
# still
#
# john
#
# kingston
#
# Concept 6:
# university
#
# time
#
# game
#
# edu
#
# two
#
# good
#
# morris
#
# really
#
# best
#
# lot
#
# Concept 7:
# game
#
# time
#
# com
#
# would
#
# even
#
# host
#
# two
#
# player
#
# posting
#
# probably
#
# Concept 8:
# baseball
#
# cs
#
# writes
#
# even
#
# team
#
# lines
#
# game
#
# ...

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:20]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu
#
# com
#
# year
#
# writes
#
# team
#
# would
#
# game
#
# article
#
# re
#
# cs
#
# baseball
#
# players
#
# games
#
# one
#
# subject
#
# good
#
# subject re
#
# organization
#
# lines
#
# think
#
# Concept 1:
# jewish
#
# players
#
# edu
#
# much
#
# writes article
#
# come
#
# princeton edu
#
# gant
#
# base
#
# article
#
# nntp
#
# princeton
#
# would
#
# player
#
# jewish baseball players
#
# lafayette
#
# lafibm
#
# vb30
#
# edu vb30
#
# lafayette edu
#
# Concept 2:
# edu
#
# writes
#
# like
#
# years
#
# many
#
# well
#
# subject
#
# know
#
# cs
#
# article
#
# john
#
# time
#
# one
#
# batting
#
# sabo
#
# three
#
# university
#
# reply
#
# mets
#
# clutch
#
# Concept 3:
# think
#
# hit
#
# posting
#
# clutch
#
# many
#
# jays
#
# good
#
# organization university
#
# pretty
#
# two
#
# year
#
# hall
#
# least
#
# player
#
# dave
#
# morris
#
# jewish
#
# david
#
# mets
#
# jack
#
# Concept 4:
# see
#
# year
#
# hirschbeck
#
# gant
#
# writes
#
# people
#
# ...

# %%
corpus[2]
# Out:
# u'From: steph@pegasus.cs.uiuc.edu (Dale Stephenson)\nSubject: "Seer" Stephenson picks the A.L. East\nSummary: The division has gone to the birds\nKeywords: last chance for foolishness\nArticle-I.D.: pegasus.steph.733989466\nOrganization: University of Illinois, Dept. of Comp. Sci., Urbana, IL\nLines: 95\n\nHaving run completely out of time, I\'ve got to get my prophesies and\npredictions for the A.L. out.  Qualifications -- one of the worse\nfinishes in last year\'s prediction contest.\n\nAL East -- 1993\n\n1.  Baltimore Orioles\nWhy the Orioles?  Well, I pondered long and hard, and it all came down to\nthis:\n  -- The Blue Jays are going the wrong direction.\n  -- Can\'t bring myself to pick the Yankees\n  -- Milwaukee was a fluke\n  -- Indians aren\'t ready to contend\n  -- Red Sox were bad last year, and didn\'t get any better\n  -- Detroit\'s pitching will be the new definition of "replacement level"\n"But you don\'t really think the Orioles will win, do you."  No.  As a matter\n
# ...

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[2]
# Out:
# <1x190577 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1293 stored elements in Compressed Sparse Row format>

# %%
print X[2]
# Out:
#   (0, 89674)	0.0153587149299
#   (0, 123280)	0.0153587149299
#   (0, 63700)	0.0153587149299
#   (0, 183774)	0.0153587149299
#   (0, 103451)	0.0153587149299
#   (0, 78011)	0.0153587149299
#   (0, 48652)	0.0153587149299
#   (0, 67173)	0.0158673916339
#   (0, 30755)	0.0158673916339
#   (0, 60343)	0.0158673916339
#   (0, 174792)	0.0158673916339
#   (0, 160058)	0.0152060039813
#   (0, 160082)	0.0152060039813
#   (0, 52178)	0.0152060039813
#   (0, 76898)	0.0225656993673
#   (0, 57091)	0.0225656993673
#   (0, 120485)	0.0225656993673
#   (0, 137307)	0.0225656993673
#   (0, 98108)	0.0225656993673
#   (0, 97647)	0.0225656993673
#   (0, 184279)	0.0225656993673
#   (0, 42597)	0.0225656993673
#   (0, 118994)	0.0225656993673
#   (0, 114643)	0.0225656993673
#   (0, 55292)	0.0225656993673
#   :	:
#   (0, 10127)	0.012618538428
#   (0, 33212)	0.0137913115286
#   (0, 37046)	0.0113494514644
#   (0, 108250)	0.0285726919963
#   (0, 129588)	0.00931314258769
#   (0, 96810)	0.048546743203
# ...

# %%
X.shape
# Out:
# (994, 190577)

# %%
lsa=TruncatedSVD(n_components=27,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=27, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01618102,  0.00504852,  0.00083791, ...,  0.00102956,
#         0.00102956,  0.00102956])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu
#
# com
#
# year
#
# writes
#
# team
#
# would
#
# game
#
# article
#
# re
#
# cs
#
# Concept 1:
# host
#
# know
#
# john
#
# way
#
# university
#
# jewish
#
# edu vb30
#
# lafayette edu
#
# lafayette edu vb30
#
# lafibm lafayette
#
# Concept 2:
# edu
#
# subject re
#
# lines
#
# game
#
# team
#
# posting
#
# organization university
#
# good
#
# didn
#
# home
#
# Concept 3:
# game
#
# gant
#
# braves
#
# team
#
# hirschbeck
#
# ibm
#
# well
#
# won
#
# baseball
#
# runs
#
# Concept 4:
# good
#
# might
#
# year
#
# win
#
# league
#
# first
#
# go
#
# games
#
# fan
#
# let
#
# Concept 5:
# com
#
# host
#
# one
#
# player
#
# really
#
# team
#
# organization
#
# better
#
# probably
#
# 10
#
# Concept 6:
# com
#
# well
#
# 10
#
# runs
#
# games
#
# game
#
# article
#
# win
#
# morris
#
# 00
#
# Concept 7:
# first
#
# season
#
# new
#
# 00
#
# two
#
# like
#
# year
#
# see
#
# player
#
# think
#
# Concept 8:
# cs
#
# organization
#
# pitcher
#
# well
#
# com
#
# one
#
# ...
